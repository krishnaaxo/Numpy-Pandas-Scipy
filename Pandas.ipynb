# %% [markdown]
# <a href="https://colab.research.google.com/github/krishnaaxo/Numpy-Pandas-Scipy/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **What is Pandas ?**
#
# Pandas is an open-source Python Library providing high-performance data manipulation and analysis tool using its powerful data structures.

# %% [markdown]
# * The pandas library is useful for dealing with structured data. What is structured data? Data
# that is stored in tables, such as CSV files, Excel spreadsheets, or database tables, is all
# structured.
# * Unstructured data consists of free form text, images, sound, or video.
# * If you find
# yourself dealing with structured data, pandas will be of great utility to you.

# %% [markdown]
# ![1Capture.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# *  The three consecutive dots, ..., in the middle of the columns indicate that there is at least one column that exists but is not displayed due to the number
# of columns exceeding the
# predefined display limits.
#
# * By default, pandas shows 60 rows and 20 columns

# %% [markdown]
# *   Pandas uses NaN (not a number) to represent missing values. Notice that even though the
# color column has string values, it uses NaN to represent a missing value.
# *   Pandas has two important components which are dataframe and series. Both having their own diffrent operations.
# *   Whenever you have a dataset with atleast two column(features) & any number of rows then we call it as dataframes.
# *   Whenever you have one column with any number of rows it's called as series.

# %% [markdown]
# **How do I read a tabular data file into pandas?**

# %%
import pandas as pd

# %%
# read a dataset of Chipotle orders directly from a URL and store the results in a DataFrame
orders = pd.read_table('http://bit.ly/chiporders')

# %%
#examine the first 5 rows
orders.head()
#examine the last 5 rows
#orders.tail()
# Out:
#    order_id  ...  item_price
# 0         1  ...      $2.39
# 1         1  ...      $3.39
# 2         1  ...      $3.39
# 3         1  ...      $2.39
# 4         2  ...     $16.98
#
# [5 rows x 5 columns]

# %% [markdown]
# Documentation for [read_table](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_table.html)

# %%
# read a dataset of movie reviewers (modifying the default parameter values for read_table)
user_cols = ['user_id', 'age', 'gender', 'occupation', 'zip_code']
users = pd.read_table('http://bit.ly/movieusers', sep='|', header=None, names=user_cols)

# %%
#examine the first 5 rows
users.head()
# Out:
#    user_id  age gender  occupation zip_code
# 0        1   24      M  technician    85711
# 1        2   53      F       other    94043
# 2        3   23      M      writer    32067
# 3        4   24      M  technician    43537
# 4        5   33      F       other    15213

# %% [markdown]
# **How to select a pandas Series from a DataFrame?**

# %%
#read a dataset of UFO report into a DataFrame
ufo = pd.read_table('http://bit.ly/uforeports', sep=',')

# %%
#read_csv is equivalent to read_table, except it assumes a comma seprator
ufo = pd.read_csv('http://bit.ly/uforeports')

# %%
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
#select the 'city' series using bracket notation
ufo['City']

#or equivalently use a dot notation
ufo.City
# Out:
# 0                      Ithaca
# 1                 Willingboro
# 2                     Holyoke
# 3                     Abilene
# 4        New York Worlds Fair
#                  ...
# 18236              Grant Park
# 18237             Spirit Lake
# 18238             Eagle River
# 18239             Eagle River
# 18240                    Ybor
# Name: City, Length: 18241, dtype: object

# %% [markdown]
# **Bracket notation** will always work, whereas dot notation has limitations:
# * Dot notation dosen't work if there are spaces int the Series name
# * Dot notation dosen't work if the Series has the same name as a **DataFrame method or attribute** (like 'head' or 'shape')
# * Dot notation can't be used to define the name of a **new Series** (see below)

# %%
#create a new 'Location' Series (must use brackets notation to define the Series name)
ufo['Location'] = ufo.City + ',' + ufo.State
ufo.head()
# Out:
#                    City  ...                 Location
# 0                Ithaca  ...                Ithaca,NY
# 1           Willingboro  ...           Willingboro,NJ
# 2               Holyoke  ...               Holyoke,CO
# 3               Abilene  ...               Abilene,KS
# 4  New York Worlds Fair  ...  New York Worlds Fair,NY
#
# [5 rows x 6 columns]

# %% [markdown]
# **Why do some pandas commands end with parentheses (and others don't)?**

# %%
# read a dataset of top-rated IMDb movies into a DataFrame
movies = pd.read_csv('http://bit.ly/imdbratings')

# %% [markdown]
# **Method** ends with prantheses, While **attributes** don't:
#
# [To know more](https://www.tutorialspoint.com/accessing-attributes-and-methods-in-python)

# %%
# example method: show the first 5 rows
movies.head()
# Out:
#    star_rating  ...                                        actors_list
# 0          9.3  ...  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1          9.2  ...    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2          9.1  ...  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3          9.0  ...  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4          8.9  ...  [u'John Travolta', u'Uma Thurman', u'Samuel L....
#
# [5 rows x 6 columns]

# %%
# examine the column names
ufo.columns
# Out:
# Index(['City', 'Colors Reported', 'Shape Reported', 'State', 'Time',
#        'Location'],
#       dtype='object')

# %%
# rename two of the columns by using the 'rename' method
ufo.rename(columns={'Colors Reported':'Colors_Reported', 'Shape Reported':'Shape_Reported'}, inplace=True)
ufo.columns
# Out:
# Index(['City', 'Colors_Reported', 'Shape_Reported', 'State', 'Time',
#        'Location'],
#       dtype='object')

# %% [markdown]
# When inplace = True is used, it performs operation on data and nothing is returned.
# When inplace=False is used, it performs operation on data and returns a new copy of data.

# %%
# replace all of the column names by overwriting the 'columns' attribute
ufo_cols = ['city', 'colors reported', 'shape reported', 'state','city','time']
ufo.columns = ufo_cols
ufo.columns
# Out:
# Index(['city', 'colors reported', 'shape reported', 'state', 'city', 'time'], dtype='object')

# %%
# replace all spaces with underscores in the column names by using the 'str.replace' method
ufo.columns = ufo.columns.str.replace(' ', '_')
ufo.columns
# Out:
# Index(['city', 'colors_reported', 'shape_reported', 'state', 'city', 'time'], dtype='object')

# %% [markdown]
# **How do I remove columns from a pandas DataFrame?**

# %%
# read a dataset of UFO reports into a DataFrame
ufo = pd.read_csv('http://bit.ly/uforeports')
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
# remove a single column (axis=1 refers to columns)
ufo.drop('Colors Reported', axis=1, inplace=True)
ufo.head()
# Out:
#                    City Shape Reported State             Time
# 0                Ithaca       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke           OVAL    CO  2/15/1931 14:00
# 3               Abilene           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair          LIGHT    NY  4/18/1933 19:00

# %%
# remove multiple columns at once
ufo.drop(['City', 'State'], axis=1, inplace=True)
ufo.head()
# Out:
#   Shape Reported             Time
# 0       TRIANGLE   6/1/1930 22:00
# 1          OTHER  6/30/1930 20:00
# 2           OVAL  2/15/1931 14:00
# 3           DISK   6/1/1931 13:00
# 4          LIGHT  4/18/1933 19:00

# %%
# remove multiple rows at once (axis=0 refers to rows)
ufo.drop([0, 1], axis=0, inplace=True)
ufo.head()
# Out:
#   Shape Reported             Time
# 2           OVAL  2/15/1931 14:00
# 3           DISK   6/1/1931 13:00
# 4          LIGHT  4/18/1933 19:00
# 5           DISK  9/15/1934 15:30
# 6         CIRCLE   6/15/1935 0:00

# %% [markdown]
# **How to sort a pandas DataFrame or a Series?**

# %%
# read a dataset of top-rated IMDb movies into a DataFrame
movies = pd.read_csv('http://bit.ly/imdbratings')
movies.head()
# Out:
#    star_rating  ...                                        actors_list
# 0          9.3  ...  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1          9.2  ...    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2          9.1  ...  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3          9.0  ...  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4          8.9  ...  [u'John Travolta', u'Uma Thurman', u'Samuel L....
#
# [5 rows x 6 columns]

# %% [markdown]
# **Note:** None of the sorting methods below affect the underlying data. (In other words, the sorting is temporary).

# %%
#sort the 'title' Series in an ascending order (return a Series)
movies.title.sort_values().head()
# Out:
# 542     (500) Days of Summer
# 5               12 Angry Men
# 201         12 Years a Slave
# 698                127 Hours
# 110    2001: A Space Odyssey
# Name: title, dtype: object

# %%
#sort in an descending order 
movies.title.sort_values(ascending=False).head()
# Out:
# 864               [Rec]
# 526                Zulu
# 615          Zombieland
# 677              Zodiac
# 955    Zero Dark Thirty
# Name: title, dtype: object

# %% [markdown]
# Documentation for [sort_Values](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.sort_values.html)

# %%
# sort the entire DataFrame by the 'title' Series (returns a DataFrame)
movies.sort_values('title').head()
# Out:
#      star_rating  ...                                        actors_list
# 542          7.8  ...  [u'Zooey Deschanel', u'Joseph Gordon-Levitt', ...
# 5            8.9  ...  [u'Henry Fonda', u'Lee J. Cobb', u'Martin Bals...
# 201          8.1  ...  [u'Chiwetel Ejiofor', u'Michael Kenneth Willia...
# 698          7.6  ...  [u'James Franco', u'Amber Tamblyn', u'Kate Mara']
# 110          8.3  ...  [u'Keir Dullea', u'Gary Lockwood', u'William S...
#
# [5 rows x 6 columns]

# %%
# sort in descending order instead
movies.sort_values('title', ascending=False).head()
# Out:
#      star_rating  ...                                        actors_list
# 864          7.5  ...  [u'Manuela Velasco', u'Ferran Terraza', u'Jorg...
# 526          7.8  ...  [u'Stanley Baker', u'Jack Hawkins', u'Ulla Jac...
# 615          7.7  ...  [u'Jesse Eisenberg', u'Emma Stone', u'Woody Ha...
# 677          7.7  ...  [u'Jake Gyllenhaal', u'Robert Downey Jr.', u'M...
# 955          7.4  ...  [u'Jessica Chastain', u'Joel Edgerton', u'Chri...
#
# [5 rows x 6 columns]

# %%
# sort the DataFrame first by 'content_rating', then by 'duration'
movies.sort_values(['content_rating', 'duration']).head()
# Out:
#      star_rating  ...                                        actors_list
# 713          7.6  ...  [u'Phil Harris', u'Sebastian Cabot', u'Louis P...
# 513          7.8  ...  [u'Kevin McCarthy', u'Dana Wynter', u'Larry Ga...
# 272          8.1  ...  [u'Sterling Hayden', u'Coleen Gray', u'Vince E...
# 703          7.6  ...  [u'Bela Lugosi', u'Helen Chandler', u'David Ma...
# 612          7.7  ...  [u'John Lennon', u'Paul McCartney', u'George H...
#
# [5 rows x 6 columns]

# %% [markdown]
# **How to filter rows of a pandas DataFrame by column value?**

# %%
# read a dataset of top-rated IMDb movies into a DataFrame
movies = pd.read_csv('http://bit.ly/imdbratings')
movies.head()
# Out:
#    star_rating  ...                                        actors_list
# 0          9.3  ...  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1          9.2  ...    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2          9.1  ...  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3          9.0  ...  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4          8.9  ...  [u'John Travolta', u'Uma Thurman', u'Samuel L....
#
# [5 rows x 6 columns]

# %%
#examine the number of rows and columns
movies.shape
# Out:
# (979, 6)

# %% [markdown]
# **Goal:** Filter the DataFrame rows to only show movies with a 'duration' of at least 200 minutes.

# %%
# create a list in which each element refers to a DataFrame row: True if the row satisfies the condition, False otherwise
booleans = []
for length in movies.duration:
    if length >= 200:
        booleans.append(True)
    else:
        booleans.append(False)

# %%
# confirm that the list has the same length as the DataFrame
len(booleans)
# Out:
# 979

# %%
# examine the first five list elements
booleans[0:5]
# Out:
# [False, False, True, False, False]

# %%
#convert the list to a series
is_long = pd.Series(booleans)
is_long.head()
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4    False
# dtype: bool

# %%
# use bracket notation with the boolean Series to tell the DataFrame which rows to display
movies[is_long]
# Out:
#      star_rating  ...                                        actors_list
# 2            9.1  ...  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 7            8.9  ...  [u'Elijah Wood', u'Viggo Mortensen', u'Ian McK...
# 17           8.7  ...  [u'Toshir\xf4 Mifune', u'Takashi Shimura', u'K...
# 78           8.4  ...  [u'Robert De Niro', u'James Woods', u'Elizabet...
# 85           8.4  ...  [u"Peter O'Toole", u'Alec Guinness', u'Anthony...
# 142          8.3  ...  [u'Aamir Khan', u'Gracy Singh', u'Rachel Shell...
# 157          8.2  ...  [u'Clark Gable', u'Vivien Leigh', u'Thomas Mit...
# 204          8.1  ...  [u'Charlton Heston', u'Jack Hawkins', u'Stephe...
# 445          7.9  ...  [u'Charlton Heston', u'Yul Brynner', u'Anne Ba...
# 476          7.8  ...  [u'Kenneth Branagh', u'Julie Christie', u'Dere...
# 630          7.7  ...  [u'Denzel Washington', u'Angela Bassett', u'De...
# 767          7.6  ...  [u'Spencer Tracy', u'Milton Berle', u'Ethel Me...
#
# ...

# %%
# simplify the steps above: no need to write a for loop to create 'is_long' since pandas will broadcast the comparison
is_long = movies.duration >= 200
movies[is_long]

# or equivalently, write it in one line (no need to create the 'is_long' object)
movies[movies.duration >= 200]
# Out:
#      star_rating  ...                                        actors_list
# 2            9.1  ...  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 7            8.9  ...  [u'Elijah Wood', u'Viggo Mortensen', u'Ian McK...
# 17           8.7  ...  [u'Toshir\xf4 Mifune', u'Takashi Shimura', u'K...
# 78           8.4  ...  [u'Robert De Niro', u'James Woods', u'Elizabet...
# 85           8.4  ...  [u"Peter O'Toole", u'Alec Guinness', u'Anthony...
# 142          8.3  ...  [u'Aamir Khan', u'Gracy Singh', u'Rachel Shell...
# 157          8.2  ...  [u'Clark Gable', u'Vivien Leigh', u'Thomas Mit...
# 204          8.1  ...  [u'Charlton Heston', u'Jack Hawkins', u'Stephe...
# 445          7.9  ...  [u'Charlton Heston', u'Yul Brynner', u'Anne Ba...
# 476          7.8  ...  [u'Kenneth Branagh', u'Julie Christie', u'Dere...
# 630          7.7  ...  [u'Denzel Washington', u'Angela Bassett', u'De...
# 767          7.6  ...  [u'Spencer Tracy', u'Milton Berle', u'Ethel Me...
#
# ...

# %%
# select the 'genre' Series from the filtered DataFrame
movies[movies.duration >= 200].genre

# or equivalently, use the 'loc' method
movies.loc[movies.duration >= 200, 'genre']
# Out:
# 2          Crime
# 7      Adventure
# 17         Drama
# 78         Crime
# 85     Adventure
# 142    Adventure
# 157        Drama
# 204    Adventure
# 445    Adventure
# 476        Drama
# 630    Biography
# 767       Action
# Name: genre, dtype: object

# %% [markdown]
# To know more about [**loc**](https://www.tutorialspoint.com/python_pandas/python_pandas_indexing_and_selecting_data.htm)

# %% [markdown]
# **How to apply multiple filter criteria to a pandas DataFrame?**

# %%
# read a dataset of top-rated IMDb movies into a DataFrame
movies = pd.read_csv('http://bit.ly/imdbratings')
movies.head()
# Out:
#    star_rating  ...                                        actors_list
# 0          9.3  ...  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1          9.2  ...    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2          9.1  ...  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3          9.0  ...  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4          8.9  ...  [u'John Travolta', u'Uma Thurman', u'Samuel L....
#
# [5 rows x 6 columns]

# %%
# filter the DataFrame to only show movies with a 'duration' of at least 200 minutes
movies[movies.duration >= 200]
# Out:
#      star_rating  ...                                        actors_list
# 2            9.1  ...  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 7            8.9  ...  [u'Elijah Wood', u'Viggo Mortensen', u'Ian McK...
# 17           8.7  ...  [u'Toshir\xf4 Mifune', u'Takashi Shimura', u'K...
# 78           8.4  ...  [u'Robert De Niro', u'James Woods', u'Elizabet...
# 85           8.4  ...  [u"Peter O'Toole", u'Alec Guinness', u'Anthony...
# 142          8.3  ...  [u'Aamir Khan', u'Gracy Singh', u'Rachel Shell...
# 157          8.2  ...  [u'Clark Gable', u'Vivien Leigh', u'Thomas Mit...
# 204          8.1  ...  [u'Charlton Heston', u'Jack Hawkins', u'Stephe...
# 445          7.9  ...  [u'Charlton Heston', u'Yul Brynner', u'Anne Ba...
# 476          7.8  ...  [u'Kenneth Branagh', u'Julie Christie', u'Dere...
# 630          7.7  ...  [u'Denzel Washington', u'Angela Bassett', u'De...
# 767          7.6  ...  [u'Spencer Tracy', u'Milton Berle', u'Ethel Me...
#
# ...

# %% [markdown]
# Understanding the **logical operators**
#
#
# *   **and**: True only if both sides of the operator are True.
# *   **or**: True only if either side of the operator is True.

# %%
#demonstration of the 'and' operator
print(True and True)
print(True and False)
print(False and False)
# Out:
# True
# False
# False

# %%
# demonstration of the 'or' operator
print(True or True)
print(True or False)
print(False or False)
# Out:
# True
# True
# False

# %% [markdown]
# Rules for specifying **multiple filter criteria in pandas**:
#
# * Use **&** instead of **and**
# * Use **|** instead of **or**
# * add **parentheses** around each condition to specity evaluation order.
#
#
# **Goal:** Further filter the DataFrame of long movies (duration >= 200) to only show movies which also have a 'genre' of 'Drama'

# %%
#CORRECT: use the '&' operator to specify that both conditions are required
movies[(movies.duration >=200) & (movies.genre == 'Drama')]
# Out:
#      star_rating  ...                                        actors_list
# 17           8.7  ...  [u'Toshir\xf4 Mifune', u'Takashi Shimura', u'K...
# 157          8.2  ...  [u'Clark Gable', u'Vivien Leigh', u'Thomas Mit...
# 476          7.8  ...  [u'Kenneth Branagh', u'Julie Christie', u'Dere...
#
# [3 rows x 6 columns]

# %%
# INCORRECT: using the '|' operator would have shown movies that are either long or dramas (or both)
movies[(movies.duration >=200) | (movies.genre == 'Drama')].head()
# Out:
#     star_rating  ...                                        actors_list
# 2           9.1  ...  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 5           8.9  ...  [u'Henry Fonda', u'Lee J. Cobb', u'Martin Bals...
# 7           8.9  ...  [u'Elijah Wood', u'Viggo Mortensen', u'Ian McK...
# 9           8.9  ...  [u'Brad Pitt', u'Edward Norton', u'Helena Bonh...
# 13          8.8  ...    [u'Tom Hanks', u'Robin Wright', u'Gary Sinise']
#
# [5 rows x 6 columns]

# %% [markdown]
# **Goal:** Filter the original DataFrame to show movies with a 'genre' of 'Crime' or 'Drama' or 'Action'

# %%
# use the '|' operator to specify that a row can match any of the three criteria
movies[(movies.genre == 'Crime') | (movies.genre == 'Drama') | (movies.genre == 'Action')].head(10)

# or equivalently, use the 'isin' method
movies[movies.genre.isin(['Crime', 'Drama', 'Action'])].head(10)
# Out:
#     star_rating  ...                                        actors_list
# 0           9.3  ...  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1           9.2  ...    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2           9.1  ...  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3           9.0  ...  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4           8.9  ...  [u'John Travolta', u'Uma Thurman', u'Samuel L....
# 5           8.9  ...  [u'Henry Fonda', u'Lee J. Cobb', u'Martin Bals...
# 9           8.9  ...  [u'Brad Pitt', u'Edward Norton', u'Helena Bonh...
# 11          8.8  ...  [u'Leonardo DiCaprio', u'Joseph Gordon-Levitt'...
# 12          8.8  ...  [u'Mark Hamill', u'Harrison Ford', u'Carrie Fi...
# 13          8.8  ...    [u'Tom Hanks', u'Robin Wright', u'Gary Sinise']
#
# [10 rows x 6 columns]

# %% [markdown]
# **isin** Operation returns a Boolean series showing whether each element in the Series is exactly contained in the passed sequence of values.

# %%
# read a dataset of alcohol consumption into a DataFrame, and check the data types
drinks = pd.read_csv('http://bit.ly/drinksbycountry')
drinks.dtypes
# Out:
# country                          object
# beer_servings                     int64
# spirit_servings                   int64
# wine_servings                     int64
# total_litres_of_pure_alcohol    float64
# continent                        object
# dtype: object

# %%
# only include numeric columns in the DataFrame
import numpy as np
drinks.select_dtypes(include=[np.number]).dtypes
# Out:
# beer_servings                     int64
# spirit_servings                   int64
# wine_servings                     int64
# total_litres_of_pure_alcohol    float64
# dtype: object

# %% [markdown]
# Resource for[ **select_dtype**](https://www.geeksforgeeks.org/python-pandas-dataframe-select_dtypes/#:~:text=Pandas%20dataframe.select_dtypes%20%28%29%20function%20return%20a%20subset%20of,those%20columns%20which%20has%20some%20specific%20data%20types.)

# %% [markdown]
# How to know whether I should pass an argument as a string or a list?

# %%
# describe all of the numeric columns
drinks.describe()
# Out:
#        beer_servings  ...  total_litres_of_pure_alcohol
# count     193.000000  ...                    193.000000
# mean      106.160622  ...                      4.717098
# std       101.143103  ...                      3.773298
# min         0.000000  ...                      0.000000
# 25%        20.000000  ...                      1.300000
# 50%        76.000000  ...                      4.200000
# 75%       188.000000  ...                      7.200000
# max       376.000000  ...                     14.400000
#
# [8 rows x 4 columns]

# %%
# pass the string 'all' to describe all columns
drinks.describe(include='all')
# Out:
#            country  beer_servings  ...  total_litres_of_pure_alcohol  continent
# count          193     193.000000  ...                    193.000000        193
# unique         193            NaN  ...                           NaN          6
# top     Montenegro            NaN  ...                           NaN     Africa
# freq             1            NaN  ...                           NaN         53
# mean           NaN     106.160622  ...                      4.717098        NaN
# std            NaN     101.143103  ...                      3.773298        NaN
# min            NaN       0.000000  ...                      0.000000        NaN
# 25%            NaN      20.000000  ...                      1.300000        NaN
# 50%            NaN      76.000000  ...                      4.200000        NaN
# 75%            NaN     188.000000  ...                      7.200000        NaN
# max            NaN     376.000000  ...                     14.400000        NaN
#
# ...

# %%
# pass a list of data types to only describe certain types
drinks.describe(include=['object', 'float64'])
# Out:
#            country  total_litres_of_pure_alcohol continent
# count          193                    193.000000       193
# unique         193                           NaN         6
# top     Montenegro                           NaN    Africa
# freq             1                           NaN        53
# mean           NaN                      4.717098       NaN
# std            NaN                      3.773298       NaN
# min            NaN                      0.000000       NaN
# 25%            NaN                      1.300000       NaN
# 50%            NaN                      4.200000       NaN
# 75%            NaN                      7.200000       NaN
# max            NaN                     14.400000       NaN

# %%
# pass a list even if you only want to describe a single data type
drinks.describe(include=['object'])
# Out:
#            country continent
# count          193       193
# unique         193         6
# top     Montenegro    Africa
# freq             1        53

# %% [markdown]
# Know more: [describe](https://www.geeksforgeeks.org/python-pandas-dataframe-describe-method/)

# %% [markdown]
# **How to use the "axis" parameter in pandas?**

# %%
# read a dataset of alcohol consumption into a DataFrame
drinks = pd.read_csv('http://bit.ly/drinksbycountry')
drinks.head()
# Out:
#        country  beer_servings  ...  total_litres_of_pure_alcohol  continent
# 0  Afghanistan              0  ...                           0.0       Asia
# 1      Albania             89  ...                           4.9     Europe
# 2      Algeria             25  ...                           0.7     Africa
# 3      Andorra            245  ...                          12.4     Europe
# 4       Angola            217  ...                           5.9     Africa
#
# [5 rows x 6 columns]

# %%
# drop a column (temporarily)
drinks.drop('continent', axis=1).head()
# Out:
#        country  beer_servings  ...  wine_servings  total_litres_of_pure_alcohol
# 0  Afghanistan              0  ...              0                           0.0
# 1      Albania             89  ...             54                           4.9
# 2      Algeria             25  ...             14                           0.7
# 3      Andorra            245  ...            312                          12.4
# 4       Angola            217  ...             45                           5.9
#
# [5 rows x 5 columns]

# %%
# drop a row (temporarily)
drinks.drop(2, axis=0).head()
# Out:
#              country  ...      continent
# 0        Afghanistan  ...           Asia
# 1            Albania  ...         Europe
# 3            Andorra  ...         Europe
# 4             Angola  ...         Africa
# 5  Antigua & Barbuda  ...  North America
#
# [5 rows x 6 columns]

# %% [markdown]
# When referring to rows or columns with the axis parameter:
#
# * axis 0 refers to rows
# * axis 1 refers to columns

# %%
# calculate the mean of each numeric column
drinks.mean()

# or equivalently, specify the axis explicitly
drinks.mean(axis=0)
# Out:
# beer_servings                   106.160622
# spirit_servings                  80.994819
# wine_servings                    49.450777
# total_litres_of_pure_alcohol      4.717098
# dtype: float64

# %%
# calculate the mean of each row
drinks.mean(axis=1).head()
# Out:
# 0      0.000
# 1     69.975
# 2      9.925
# 3    176.850
# 4     81.225
# dtype: float64

# %% [markdown]
# When performing a mathematical operation with the axis parameter:
#
# * axis 0 means the operation should "move down" the row axis
# * axis 1 means the operation should "move across" the column axis

# %%
# 'index' is an alias for axis 0
drinks.mean(axis='index')
# Out:
# beer_servings                   106.160622
# spirit_servings                  80.994819
# wine_servings                    49.450777
# total_litres_of_pure_alcohol      4.717098
# dtype: float64

# %% [markdown]
# **How do I use string methods in pandas?**

# %%
# read a dataset of Chipotle orders into a DataFrame
orders = pd.read_table('http://bit.ly/chiporders')
orders.head()
# Out:
#    order_id  ...  item_price
# 0         1  ...      $2.39
# 1         1  ...      $3.39
# 2         1  ...      $3.39
# 3         1  ...      $2.39
# 4         2  ...     $16.98
#
# [5 rows x 5 columns]

# %%
# normal way to access string methods in Python
'hello'.upper()
# Out:
# 'HELLO'

# %%
# string methods for pandas Series are accessed via 'str'
orders.item_name.str.upper().head()
# Out:
# 0             CHIPS AND FRESH TOMATO SALSA
# 1                                     IZZE
# 2                         NANTUCKET NECTAR
# 3    CHIPS AND TOMATILLO-GREEN CHILI SALSA
# 4                             CHICKEN BOWL
# Name: item_name, dtype: object

# %%
# string method 'contains' checks for a substring and returns a boolean Series
orders.item_name.str.contains('Chicken').head()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# Name: item_name, dtype: bool

# %%
# use the boolean Series to filter the DataFrame
orders[orders.item_name.str.contains('Chicken')].head()
# Out:
#     order_id  ...  item_price
# 4          2  ...     $16.98
# 5          3  ...     $10.98
# 11         6  ...      $8.75
# 12         6  ...      $8.75
# 13         7  ...     $11.25
#
# [5 rows x 5 columns]

# %%
# string methods can be chained together
orders.choice_description.str.replace('[', '').str.replace(']', '').head()
# Out:
# 0                                                  NaN
# 1                                           Clementine
# 2                                                Apple
# 3                                                  NaN
# 4    Tomatillo-Red Chili Salsa (Hot), Black Beans, ...
# Name: choice_description, dtype: object

# %%
# many pandas string methods support regular expressions (regex)
orders.choice_description.str.replace('[\[\]]', '').head()
# Out:
# 0                                                  NaN
# 1                                           Clementine
# 2                                                Apple
# 3                                                  NaN
# 4    Tomatillo-Red Chili Salsa (Hot), Black Beans, ...
# Name: choice_description, dtype: object

# %% [markdown]
# know more: [Regex](https://docs.python.org/3/howto/regex.html#:~:text=Regular%20expressions%20%28called%20REs%2C%20or%20regexes%2C%20or%20regex,Python%20and%20made%20available%20through%20the%20re%20module.)

# %% [markdown]
# **How do I change the data type of a pandas Series**

# %%
# read a dataset of alcohol consumption into a DataFrame
drinks = pd.read_csv('http://bit.ly/drinksbycountry')
drinks.head()
# Out:
#        country  beer_servings  ...  total_litres_of_pure_alcohol  continent
# 0  Afghanistan              0  ...                           0.0       Asia
# 1      Albania             89  ...                           4.9     Europe
# 2      Algeria             25  ...                           0.7     Africa
# 3      Andorra            245  ...                          12.4     Europe
# 4       Angola            217  ...                           5.9     Africa
#
# [5 rows x 6 columns]

# %%
# examine the data type of each Series
drinks.dtypes
# Out:
# country                          object
# beer_servings                     int64
# spirit_servings                   int64
# wine_servings                     int64
# total_litres_of_pure_alcohol    float64
# continent                        object
# dtype: object

# %%
# change the data type of an existing Series
drinks['beer_servings'] = drinks.beer_servings.astype(float)
drinks.dtypes
# Out:
# country                          object
# beer_servings                   float64
# spirit_servings                   int64
# wine_servings                     int64
# total_litres_of_pure_alcohol    float64
# continent                        object
# dtype: object

# %% [markdown]
# Know more: [astype](https://www.askpython.com/python/built-in-methods/python-astype#:~:text=Python%20astype%20%28%29%20method%20enables%20us%20to%20set,to%20altogether%20another%20form%20using%20astype%20%28%29%20function.)

# %%
# alternatively, change the data type of a Series while reading in a file
drinks = pd.read_csv('http://bit.ly/drinksbycountry', dtype={'beer_servings':float})
drinks.dtypes
# Out:
# country                          object
# beer_servings                   float64
# spirit_servings                   int64
# wine_servings                     int64
# total_litres_of_pure_alcohol    float64
# continent                        object
# dtype: object

# %%
# read a dataset of Chipotle orders into a DataFrame
orders = pd.read_table('http://bit.ly/chiporders')
orders.head()
# Out:
#    order_id  ...  item_price
# 0         1  ...      $2.39
# 1         1  ...      $3.39
# 2         1  ...      $3.39
# 3         1  ...      $2.39
# 4         2  ...     $16.98
#
# [5 rows x 5 columns]

# %%
# examine the data type of each Series
orders.dtypes
# Out:
# order_id               int64
# quantity               int64
# item_name             object
# choice_description    object
# item_price            object
# dtype: object

# %%
# convert a string to a number in order to do math
orders.item_price.str.replace('$', '').astype(float).mean()
# Out:
# 7.464335785374397

# %%
# string method 'contains' checks for a substring and returns a boolean Series
orders.item_name.str.contains('Chicken').head()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# Name: item_name, dtype: bool

# %%
# convert a boolean Series to an integer (False = 0, True = 1)
orders.item_name.str.contains('Chicken').astype(int).head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    1
# Name: item_name, dtype: int64

# %% [markdown]
# **When should you use a "groupby" in pandas?**

# %%
# read a dataset of alcohol consumption into a DataFrame
drinks = pd.read_csv('http://bit.ly/drinksbycountry')
drinks.head()
# Out:
#        country  beer_servings  ...  total_litres_of_pure_alcohol  continent
# 0  Afghanistan              0  ...                           0.0       Asia
# 1      Albania             89  ...                           4.9     Europe
# 2      Algeria             25  ...                           0.7     Africa
# 3      Andorra            245  ...                          12.4     Europe
# 4       Angola            217  ...                           5.9     Africa
#
# [5 rows x 6 columns]

# %%
# calculate the mean beer servings across the entire dataset
drinks.beer_servings.mean()
# Out:
# 106.16062176165804

# %%
# calculate the mean beer servings just for countries in Africa
drinks[drinks.continent=='Africa'].beer_servings.mean()
# Out:
# 61.471698113207545

# %%
# calculate the mean beer servings for each continent
drinks.groupby('continent').beer_servings.mean()
# Out:
# continent
# Africa            61.471698
# Asia              37.045455
# Europe           193.777778
# North America    145.434783
# Oceania           89.687500
# South America    175.083333
# Name: beer_servings, dtype: float64

# %% [markdown]
# Know more: [groupby](https://www.askpython.com/python-modules/pandas/pandas-groupby-function)

# %%
# other aggregation functions (such as 'max') can also be used with groupby
drinks.groupby('continent').beer_servings.max()
# Out:
# continent
# Africa           376
# Asia             247
# Europe           361
# North America    285
# Oceania          306
# South America    333
# Name: beer_servings, dtype: int64

# %%
# multiple aggregation functions can be applied simultaneously
drinks.groupby('continent').beer_servings.agg(['count', 'mean', 'min', 'max'])
# Out:
#                count        mean  min  max
# continent
# Africa            53   61.471698    0  376
# Asia              44   37.045455    0  247
# Europe            45  193.777778    0  361
# North America     23  145.434783    1  285
# Oceania           16   89.687500    0  306
# South America     12  175.083333   93  333

# %% [markdown]
# Know more: [agg](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.core.groupby.DataFrameGroupBy.agg.html)

# %%
# specifying a column to which the aggregation function should be applied is not required
drinks.groupby('continent').mean()
# Out:
#                beer_servings  ...  total_litres_of_pure_alcohol
# continent                     ...
# Africa             61.471698  ...                      3.007547
# Asia               37.045455  ...                      2.170455
# Europe            193.777778  ...                      8.617778
# North America     145.434783  ...                      5.995652
# Oceania            89.687500  ...                      3.381250
# South America     175.083333  ...                      6.308333
#
# [6 rows x 4 columns]

# %%
# allow plots to appear in the notebook
# %matplotlib inline

# %%
# side-by-side bar plot of the DataFrame directly above
drinks.groupby('continent').mean().plot(kind='bar')

# %% [markdown]
# Know more: [plot](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.plot.html)

# %% [markdown]
# **How to explore a pandas Series?**

# %%
# read a dataset of top-rated IMDb movies into a DataFrame
movies = pd.read_csv('http://bit.ly/imdbratings')
movies.head()
# Out:
#    star_rating  ...                                        actors_list
# 0          9.3  ...  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1          9.2  ...    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2          9.1  ...  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3          9.0  ...  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4          8.9  ...  [u'John Travolta', u'Uma Thurman', u'Samuel L....
#
# [5 rows x 6 columns]

# %%
# examine the data type of each Series
movies.dtypes
# Out:
# star_rating       float64
# title              object
# content_rating     object
# genre              object
# duration            int64
# actors_list        object
# dtype: object

# %% [markdown]
# **Exploring a non-numeric Series:**

# %%
# count the non-null values, unique values, and frequency of the most common value
movies.genre.describe()
# Out:
# count       979
# unique       16
# top       Drama
# freq        278
# Name: genre, dtype: object

# %%
# count how many times each value in the Series occurs
movies.genre.value_counts()
# Out:
# Drama        278
# Comedy       156
# Action       136
# Crime        124
# Biography     77
# Adventure     75
# Animation     62
# Horror        29
# Mystery       16
# Western        9
# Thriller       5
# Sci-Fi         5
# Film-Noir      3
# Family         2
# History        1
# Fantasy        1
# Name: genre, dtype: int64

# %% [markdown]
# Know more: [value_counts](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.Series.value_counts.html)

# %%
# display percentages instead of raw counts
movies.genre.value_counts(normalize=True)
# Out:
# Drama        0.283963
# Comedy       0.159346
# Action       0.138917
# Crime        0.126660
# Biography    0.078652
# Adventure    0.076609
# Animation    0.063330
# Horror       0.029622
# Mystery      0.016343
# Western      0.009193
# Thriller     0.005107
# Sci-Fi       0.005107
# Film-Noir    0.003064
# Family       0.002043
# History      0.001021
# Fantasy      0.001021
# Name: genre, dtype: float64

# %%
# 'value_counts' (like many pandas methods) outputs a Series
type(movies.genre.value_counts())
# Out:
# pandas.core.series.Series

# %%
# thus, you can add another Series method on the end
movies.genre.value_counts().head()
# Out:
# Drama        278
# Comedy       156
# Action       136
# Crime        124
# Biography     77
# Name: genre, dtype: int64

# %%
# display the unique values in the Series
movies.genre.unique()
# Out:
# array(['Crime', 'Action', 'Drama', 'Western', 'Adventure', 'Biography',
#        'Comedy', 'Animation', 'Mystery', 'Horror', 'Film-Noir', 'Sci-Fi',
#        'History', 'Thriller', 'Family', 'Fantasy'], dtype=object)

# %%
# count the number of unique values in the Series
movies.genre.nunique()
# Out:
# 16

# %% [markdown]
# Know more: [unique](https://www.askpython.com/python/built-in-methods/unique-values-from-a-dataframe)

# %%
# compute a cross-tabulation of two Series
pd.crosstab(movies.genre, movies.content_rating)
# Out:
# content_rating  APPROVED   G  GP  NC-17  ...    R  TV-MA  UNRATED  X
# genre                                    ...
# Action                 3   1   1      0  ...   67      0        3  0
# Adventure              3   2   0      0  ...   17      0        2  0
# Animation              3  20   0      0  ...    5      0        1  0
# Biography              1   2   1      0  ...   36      0        0  0
# Comedy                 9   2   1      1  ...   73      0        4  1
# Crime                  6   0   0      1  ...   87      0       11  1
# Drama                 12   3   0      4  ...  143      1        9  1
# Family                 0   1   0      0  ...    0      0        0  0
# Fantasy                0   0   0      0  ...    1      0        0  0
# Film-Noir              1   0   0      0  ...    0      0        1  0
# History                0   0   0      0  ...    0      0        1  0
# Horror                 2   0   0      1  ...   16      0        5  1
# ...

# %% [markdown]
# Know more: [crosstable](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.crosstab.html)

# %% [markdown]
# **Exploring a numeric Series:**

# %%
# calculate various summary statistics
movies.duration.describe()
# Out:
# count    979.000000
# mean     120.979571
# std       26.218010
# min       64.000000
# 25%      102.000000
# 50%      117.000000
# 75%      134.000000
# max      242.000000
# Name: duration, dtype: float64

# %%
# many statistics are implemented as Series methods
movies.duration.mean()
# Out:
# 120.97957099080695

# %%
# 'value_counts' is primarily useful for categorical data, not numerical data
movies.duration.value_counts().head()
# Out:
# 112    23
# 113    22
# 102    20
# 101    20
# 129    19
# Name: duration, dtype: int64

# %%
# allow plots to appear in the notebook
# %matplotlib inline

# %%
# histogram of the 'duration' Series (shows the distribution of a numerical variable)
movies.duration.plot(kind='hist')

# %%
# bar plot of the 'value_counts' for the 'genre' Series
movies.genre.value_counts().plot(kind='bar')

# %% [markdown]
# **How to handle missing values in pandas**

# %%
# read a dataset of UFO reports into a DataFrame
ufo = pd.read_csv('http://bit.ly/uforeports')
ufo.tail()
# Out:
#               City Colors Reported Shape Reported State              Time
# 18236   Grant Park             NaN       TRIANGLE    IL  12/31/2000 23:00
# 18237  Spirit Lake             NaN           DISK    IA  12/31/2000 23:00
# 18238  Eagle River             NaN            NaN    WI  12/31/2000 23:45
# 18239  Eagle River             RED          LIGHT    WI  12/31/2000 23:45
# 18240         Ybor             NaN           OVAL    FL  12/31/2000 23:59

# %%
# 'isnull' returns a DataFrame of booleans (True if missing, False if not missing)
ufo.isnull().tail()
# Out:
#         City  Colors Reported  Shape Reported  State   Time
# 18236  False             True           False  False  False
# 18237  False             True           False  False  False
# 18238  False             True            True  False  False
# 18239  False            False           False  False  False
# 18240  False             True           False  False  False

# %%
# 'nonnull' returns the opposite of 'isnull' (True if not missing, False if missing)
ufo.notnull().tail()
# Out:
#        City  Colors Reported  Shape Reported  State  Time
# 18236  True            False            True   True  True
# 18237  True            False            True   True  True
# 18238  True            False           False   True  True
# 18239  True             True            True   True  True
# 18240  True            False            True   True  True

# %%
# count the number of missing values in each Series
ufo.isnull().sum()
# Out:
# City                  25
# Colors Reported    15359
# Shape Reported      2644
# State                  0
# Time                   0
# dtype: int64

# %% [markdown]
# This calculation works because:
#
#
#
# 1. The sum method for a DataFrame operates on axis=0 by default (and thus produces column sums).
# 2. In order to add boolean values, pandas converts True to 1 and False to 0.

# %%
# use the 'isnull' Series method to filter the DataFrame rows
ufo[ufo.City.isnull()].head()
# Out:
#     City Colors Reported Shape Reported State             Time
# 21   NaN             NaN            NaN    LA   8/15/1943 0:00
# 22   NaN             NaN          LIGHT    LA   8/15/1943 0:00
# 204  NaN             NaN           DISK    CA  7/15/1952 12:30
# 241  NaN            BLUE           DISK    MT   7/4/1953 14:00
# 613  NaN             NaN           DISK    NV   7/1/1960 12:00

# %% [markdown]
# **How to handle missing values** depends on the dataset as well as the nature of your analysis. Here are some options:

# %%
# examine the number of rows and columns
ufo.shape
# Out:
# (18241, 5)

# %%
# if 'any' values are missing in a row, then drop that row
ufo.dropna(how='any').shape
# Out:
# (2486, 5)

# %%
# 'inplace' parameter for 'dropna' is False by default, thus rows were only dropped temporarily
ufo.shape
# Out:
# (18241, 5)

# %%
# if 'all' values are missing in a row, then drop that row (none are dropped in this case)
ufo.dropna(how='all').shape
# Out:
# (18241, 5)

# %%
# if 'any' values are missing in a row (considering only 'City' and 'Shape Reported'), then drop that row
ufo.dropna(subset=['City', 'Shape Reported'], how='any').shape
# Out:
# (15576, 5)

# %%
# if 'all' values are missing in a row (considering only 'City' and 'Shape Reported'), then drop that row
ufo.dropna(subset=['City', 'Shape Reported'], how='all').shape
# Out:
# (18237, 5)

# %%
# 'value_counts' does not include missing values by default
ufo['Shape Reported'].value_counts().head()
# Out:
# LIGHT       2803
# DISK        2122
# TRIANGLE    1889
# OTHER       1402
# CIRCLE      1365
# Name: Shape Reported, dtype: int64

# %%
# explicitly include missing values
ufo['Shape Reported'].value_counts(dropna=False).head()
# Out:
# LIGHT       2803
# NaN         2644
# DISK        2122
# TRIANGLE    1889
# OTHER       1402
# Name: Shape Reported, dtype: int64

# %%
# fill in missing values with a specified value
ufo['Shape Reported'].fillna(value='VARIOUS', inplace=True)

# %%
# confirm that the missing values were filled in
ufo['Shape Reported'].value_counts().head()
# Out:
# VARIOUS     2977
# LIGHT       2803
# DISK        2122
# TRIANGLE    1889
# OTHER       1402
# Name: Shape Reported, dtype: int64

# %% [markdown]
# To know more: [missing data in pandas](https://pandas.pydata.org/pandas-docs/stable/user_guide/missing_data.html)

# %% [markdown]
#  **know about the pandas index**

# %%
# read a dataset of alcohol consumption into a DataFrame
drinks = pd.read_csv('http://bit.ly/drinksbycountry')
drinks.head()
# Out:
#        country  beer_servings  ...  total_litres_of_pure_alcohol  continent
# 0  Afghanistan              0  ...                           0.0       Asia
# 1      Albania             89  ...                           4.9     Europe
# 2      Algeria             25  ...                           0.7     Africa
# 3      Andorra            245  ...                          12.4     Europe
# 4       Angola            217  ...                           5.9     Africa
#
# [5 rows x 6 columns]

# %%
# every DataFrame has an index
drinks.index
# Out:
# RangeIndex(start=0, stop=193, step=1)

# %%
# every Series also has an index (which carries over from the DataFrame)
drinks.continent.head()
# Out:
# 0      Asia
# 1    Europe
# 2    Africa
# 3    Europe
# 4    Africa
# Name: continent, dtype: object

# %%
# set 'country' as the index
drinks.set_index('country', inplace=True)

# %%
# another example of a Series (output from the 'value_counts' method)
drinks.continent.value_counts()
# Out:
# Africa           53
# Europe           45
# Asia             44
# North America    23
# Oceania          16
# South America    12
# Name: continent, dtype: int64

# %%
# access the Series index
drinks.continent.value_counts().index
# Out:
# Index(['Africa', 'Europe', 'Asia', 'North America', 'Oceania',
#        'South America'],
#       dtype='object')

# %%
# access the Series values
drinks.continent.value_counts().values
# Out:
# array([53, 45, 44, 23, 16, 12])

# %%
# elements in a Series can be selected by index (using bracket notation)
drinks.continent.value_counts()['Africa']
# Out:
# 53

# %%
# any Series can be sorted by its values
drinks.continent.value_counts().sort_values()
# Out:
# South America    12
# Oceania          16
# North America    23
# Asia             44
# Europe           45
# Africa           53
# Name: continent, dtype: int64

# %%
# any Series can also be sorted by its index
drinks.continent.value_counts().sort_index()
# Out:
# Africa           53
# Asia             44
# Europe           45
# North America    23
# Oceania          16
# South America    12
# Name: continent, dtype: int64

# %% [markdown]
# What is the index used for?
#
# 1. identification (covered in the previous video)
# 2. selection (covered in the previous video)
# 3. alignment

# %%
# 'beer_servings' Series contains the average annual beer servings per person
drinks.beer_servings.head()
# Out:
# country
# Afghanistan      0
# Albania         89
# Algeria         25
# Andorra        245
# Angola         217
# Name: beer_servings, dtype: int64

# %%
# create a Series containing the population of two countries
people = pd.Series([3000000, 85000], index=['Albania', 'Andorra'], name='population')
people
# Out:
# Albania    3000000
# Andorra      85000
# Name: population, dtype: int64

# %%
# calculate the total annual beer servings for each country
(drinks.beer_servings * people).head()
# Out:
# Afghanistan            NaN
# Albania        267000000.0
# Algeria                NaN
# Andorra         20825000.0
# Angola                 NaN
# dtype: float64

# %% [markdown]
# * The two Series were aligned by their indexes.
# * If a value is missing in either Series, the result is marked as NaN.
# * Alignment enables us to easily work with incomplete data.

# %%
# concatenate the 'drinks' DataFrame with the 'population' Series (aligns by the index)
pd.concat([drinks, people], axis=1).head()
# Out:
#              beer_servings  spirit_servings  ...  continent  population
# Afghanistan              0                0  ...       Asia         NaN
# Albania                 89              132  ...     Europe   3000000.0
# Algeria                 25                0  ...     Africa         NaN
# Andorra                245              138  ...     Europe     85000.0
# Angola                 217               57  ...     Africa         NaN
#
# [5 rows x 6 columns]

# %% [markdown]
# Know more [concat](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.concat.html)

# %% [markdown]
# **How to select multiple rows and columns from a pandas DataFrame?**

# %%
# read a dataset of UFO reports into a DataFrame
ufo = pd.read_csv('http://bit.ly/uforeports')
ufo.head(3)
# Out:
#           City Colors Reported Shape Reported State             Time
# 0       Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1  Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2      Holyoke             NaN           OVAL    CO  2/15/1931 14:00

# %% [markdown]
# The **loc** method is used to select rows and columns by label. You can pass a:
#
# * A single label
# * A list of labels
# * A slice of labels
# * A boolean Series
# * A colon (which indicates "all labels")

# %%
# row 0, all columns
ufo.loc[0, :]
# Out:
# City                       Ithaca
# Colors Reported               NaN
# Shape Reported           TRIANGLE
# State                          NY
# Time               6/1/1930 22:00
# Name: 0, dtype: object

# %%
# rows 0 and 1 and 2, all columns
ufo.loc[[0, 1, 2], :]
# Out:
#           City Colors Reported Shape Reported State             Time
# 0       Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1  Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2      Holyoke             NaN           OVAL    CO  2/15/1931 14:00

# %%
# rows 0 through 2 (inclusive), all columns
ufo.loc[0:2, :]
# Out:
#           City Colors Reported Shape Reported State             Time
# 0       Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1  Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2      Holyoke             NaN           OVAL    CO  2/15/1931 14:00

# %%
# this implies "all columns", but explicitly stating "all columns" is better
ufo.loc[0:2]
# Out:
#           City Colors Reported Shape Reported State             Time
# 0       Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1  Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2      Holyoke             NaN           OVAL    CO  2/15/1931 14:00

# %%
# rows 0 through 2 (inclusive), column 'City'
ufo.loc[0:2, 'City']
# Out:
# 0         Ithaca
# 1    Willingboro
# 2        Holyoke
# Name: City, dtype: object

# %%
# rows 0 through 2 (inclusive), columns 'City' and 'State'
ufo.loc[0:2, ['City', 'State']]
# Out:
#           City State
# 0       Ithaca    NY
# 1  Willingboro    NJ
# 2      Holyoke    CO

# %%
# accomplish the same thing using double brackets - but using 'loc' is preferred since it's more explicit
ufo[['City', 'State']].head(3)
# Out:
#           City State
# 0       Ithaca    NY
# 1  Willingboro    NJ
# 2      Holyoke    CO

# %%
# rows 0 through 2 (inclusive), columns 'City' through 'State' (inclusive)
ufo.loc[0:2, 'City':'State']
# Out:
#           City Colors Reported Shape Reported State
# 0       Ithaca             NaN       TRIANGLE    NY
# 1  Willingboro             NaN          OTHER    NJ
# 2      Holyoke             NaN           OVAL    CO

# %%
# accomplish the same thing using 'head' and 'drop'
ufo.head(3).drop('Time', axis=1)
# Out:
#           City Colors Reported Shape Reported State
# 0       Ithaca             NaN       TRIANGLE    NY
# 1  Willingboro             NaN          OTHER    NJ
# 2      Holyoke             NaN           OVAL    CO

# %%
# rows in which the 'City' is 'Oakland', column 'State'
ufo.loc[ufo.City=='Oakland', 'State']
# Out:
# 1694     CA
# 2144     CA
# 4686     MD
# 7293     CA
# 8488     CA
# 8768     CA
# 10816    OR
# 10948    CA
# 11045    CA
# 12322    CA
# 12941    CA
# 16803    MD
# 17322    CA
# Name: State, dtype: object

# %%
# accomplish the same thing using "chained indexing" - but using 'loc' is preferred since chained indexing can cause problems
ufo[ufo.City=='Oakland'].State
# Out:
# 1694     CA
# 2144     CA
# 4686     MD
# 7293     CA
# 8488     CA
# 8768     CA
# 10816    OR
# 10948    CA
# 11045    CA
# 12322    CA
# 12941    CA
# 16803    MD
# 17322    CA
# Name: State, dtype: object

# %% [markdown]
# The **iloc** method is used to select rows and columns by integer position. You can pass it:
#
# * A single integer position
# * A list of integer positions
# * A slice of integer positions
# * A colon (which indicates "all integer positions")

# %%
# rows in positions 0 and 1, columns in positions 0 and 3
ufo.iloc[[0, 1], [0, 3]]
# Out:
#           City State
# 0       Ithaca    NY
# 1  Willingboro    NJ

# %%
# rows in positions 0 through 2 (exclusive), all columns
ufo.iloc[0:2, :]
# Out:
#           City Colors Reported Shape Reported State             Time
# 0       Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1  Willingboro             NaN          OTHER    NJ  6/30/1930 20:00

# %%
# accomplish the same thing - but using 'iloc' is preferred since it's more explicit
ufo[0:2]
# Out:
#           City Colors Reported Shape Reported State             Time
# 0       Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1  Willingboro             NaN          OTHER    NJ  6/30/1930 20:00

# %% [markdown]
# **How do make pandas DataFrame smaller and faster**

# %%
# read a dataset of alcohol consumption into a DataFrame
drinks = pd.read_csv('http://bit.ly/drinksbycountry')
drinks.head()
# Out:
#        country  beer_servings  ...  total_litres_of_pure_alcohol  continent
# 0  Afghanistan              0  ...                           0.0       Asia
# 1      Albania             89  ...                           4.9     Europe
# 2      Algeria             25  ...                           0.7     Africa
# 3      Andorra            245  ...                          12.4     Europe
# 4       Angola            217  ...                           5.9     Africa
#
# [5 rows x 6 columns]

# %%
# exact memory usage is unknown because object columns are references elsewhere
drinks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 6 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   country                       193 non-null    object
#  1   beer_servings                 193 non-null    int64
#  2   spirit_servings               193 non-null    int64
#  3   wine_servings                 193 non-null    int64
#  4   total_litres_of_pure_alcohol  193 non-null    float64
#  5   continent                     193 non-null    object
# dtypes: float64(1), int64(3), object(2)
# memory usage: 9.2+ KB

# %%
# force pandas to calculate the true memory usage
drinks.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 6 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   country                       193 non-null    object
#  1   beer_servings                 193 non-null    int64
#  2   spirit_servings               193 non-null    int64
#  3   wine_servings                 193 non-null    int64
#  4   total_litres_of_pure_alcohol  193 non-null    float64
#  5   continent                     193 non-null    object
# dtypes: float64(1), int64(3), object(2)
# memory usage: 30.5 KB

# %%
# calculate the memory usage for each Series (in bytes)
drinks.memory_usage(deep=True)
# Out:
# Index                             128
# country                         12588
# beer_servings                    1544
# spirit_servings                  1544
# wine_servings                    1544
# total_litres_of_pure_alcohol     1544
# continent                       12332
# dtype: int64

# %% [markdown]
# Know more [info](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.info.html) [memory_usage](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.memory_usage.html)

# %%
# use the 'category' data type to store the 'continent' strings as integers
drinks['continent'] = drinks.continent.astype('category')
drinks.dtypes
# Out:
# country                           object
# beer_servings                      int64
# spirit_servings                    int64
# wine_servings                      int64
# total_litres_of_pure_alcohol     float64
# continent                       category
# dtype: object

# %%
# 'continent' Series appears to be unchanged
drinks.continent.head()
# Out:
# 0      Asia
# 1    Europe
# 2    Africa
# 3    Europe
# 4    Africa
# Name: continent, dtype: category
# Categories (6, object): ['Africa', 'Asia', 'Europe', 'North America', 'Oceania', 'South America']

# %%
# strings are now encoded (0 means 'Africa', 1 means 'Asia', 2 means 'Europe', etc.)
drinks.continent.cat.codes.head()
# Out:
# 0    1
# 1    2
# 2    0
# 3    2
# 4    0
# dtype: int8

# %%
# memory usage has been drastically reduced
drinks.memory_usage(deep=True)
# Out:
# Index                             128
# country                         12588
# beer_servings                    1544
# spirit_servings                  1544
# wine_servings                    1544
# total_litres_of_pure_alcohol     1544
# continent                         744
# dtype: int64

# %%
# repeat this process for the 'country' Series
drinks['country'] = drinks.country.astype('category')
drinks.memory_usage(deep=True)
# Out:
# Index                             128
# country                         18094
# beer_servings                    1544
# spirit_servings                  1544
# wine_servings                    1544
# total_litres_of_pure_alcohol     1544
# continent                         744
# dtype: int64

# %%
# memory usage increased because we created 193 categories
drinks.country.cat.categories
# Out:
# Index(['Afghanistan', 'Albania', 'Algeria', 'Andorra', 'Angola',
#        'Antigua & Barbuda', 'Argentina', 'Armenia', 'Australia', 'Austria',
#        ...
#        'United Arab Emirates', 'United Kingdom', 'Uruguay', 'Uzbekistan',
#        'Vanuatu', 'Venezuela', 'Vietnam', 'Yemen', 'Zambia', 'Zimbabwe'],
#       dtype='object', length=193)

# %% [markdown]
# The **category** data type should only be used with a string Series that has a small number of **possible values**.

# %%
# create a small DataFrame from a dictionary
df = pd.DataFrame({'ID':[100, 101, 102, 103], 'quality':['good', 'very good', 'good', 'excellent']})
df
# Out:
#     ID    quality
# 0  100       good
# 1  101  very good
# 2  102       good
# 3  103  excellent

# %%
# sort the DataFrame by the 'quality' Series (alphabetical order)
df.sort_values('quality')
# Out:
#     ID    quality
# 3  103  excellent
# 0  100       good
# 2  102       good
# 1  101  very good

# %%
# sort the DataFrame by the 'quality' Series (logical order)
df.sort_values('quality')
# Out:
#     ID    quality
# 3  103  excellent
# 0  100       good
# 2  102       good
# 1  101  very good

# %%
# comparison operators work with ordered categories
df.loc[df.quality > 'good', :]
# Out:
#     ID    quality
# 1  101  very good

# %% [markdown]
# **How to create dummy variables in pandas**

# %%
# read the training dataset from Kaggle's Titanic competition
train = pd.read_csv('http://bit.ly/kaggletrain')
train.head()
# Out:
#    PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0            1         0       3  ...   7.2500   NaN         S
# 1            2         1       1  ...  71.2833   C85         C
# 2            3         1       3  ...   7.9250   NaN         S
# 3            4         1       1  ...  53.1000  C123         S
# 4            5         0       3  ...   8.0500   NaN         S
#
# [5 rows x 12 columns]

# %%
# create the 'Sex_male' dummy variable using the 'map' method
train['Sex_male'] = train.Sex.map({'female':0, 'male':1})
train.head()
# Out:
#    PassengerId  Survived  Pclass  ... Cabin Embarked  Sex_male
# 0            1         0       3  ...   NaN        S         1
# 1            2         1       1  ...   C85        C         0
# 2            3         1       3  ...   NaN        S         0
# 3            4         1       1  ...  C123        S         0
# 4            5         0       3  ...   NaN        S         1
#
# [5 rows x 13 columns]

# %% [markdown]
# Documentation for [map](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.Series.map.html)

# %%
# alternative: use 'get_dummies' to create one column for every possible value
pd.get_dummies(train.Sex).head()
# Out:
#    female  male
# 0       0     1
# 1       1     0
# 2       1     0
# 3       1     0
# 4       0     1

# %% [markdown]
# * If you have "K" possible values for a categorical feature, you only need "K-1" dummy variables to capture all of the information about that feature.
# * One convention is to drop the first dummy variable, which defines that level as the "baseline".

# %%
# drop the first dummy variable ('female') using the 'iloc' method
pd.get_dummies(train.Sex).iloc[:, 1:].head()
# Out:
#    male
# 0     1
# 1     0
# 2     0
# 3     0
# 4     1

# %%
# add a prefix to identify the source of the dummy variables
pd.get_dummies(train.Sex, prefix='Sex').iloc[:, 1:].head()
# Out:
#    Sex_male
# 0         1
# 1         0
# 2         0
# 3         0
# 4         1

# %%
# use 'get_dummies' with a feature that has 3 possible values
pd.get_dummies(train.Embarked, prefix='Embarked').head(10)
# Out:
#    Embarked_C  Embarked_Q  Embarked_S
# 0           0           0           1
# 1           1           0           0
# 2           0           0           1
# 3           0           0           1
# 4           0           0           1
# 5           0           1           0
# 6           0           0           1
# 7           0           0           1
# 8           0           0           1
# 9           1           0           0

# %%
# drop the first dummy variable ('C')
pd.get_dummies(train.Embarked, prefix='Embarked').iloc[:, 1:].head(10)
# Out:
#    Embarked_Q  Embarked_S
# 0           0           1
# 1           0           0
# 2           0           1
# 3           0           1
# 4           0           1
# 5           1           0
# 6           0           1
# 7           0           1
# 8           0           1
# 9           0           0

# %% [markdown]
# How to translate these values back to the original 'Embarked' value:
#
# * 0, 0 means C
# * 1, 0 means Q
# * 0, 1 means S

# %%
# save the DataFrame of dummy variables and concatenate them to the original DataFrame
embarked_dummies = pd.get_dummies(train.Embarked, prefix='Embarked').iloc[:, 1:]
train = pd.concat([train, embarked_dummies], axis=1)
train.head()
# Out:
#    PassengerId  Survived  Pclass  ... Sex_male Embarked_Q  Embarked_S
# 0            1         0       3  ...        1          0           1
# 1            2         1       1  ...        0          0           0
# 2            3         1       3  ...        0          0           1
# 3            4         1       1  ...        0          0           1
# 4            5         0       3  ...        1          0           1
#
# [5 rows x 15 columns]

# %%
# reset the DataFrame
train = pd.read_csv('http://bit.ly/kaggletrain')
train.head()
# Out:
#    PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0            1         0       3  ...   7.2500   NaN         S
# 1            2         1       1  ...  71.2833   C85         C
# 2            3         1       3  ...   7.9250   NaN         S
# 3            4         1       1  ...  53.1000  C123         S
# 4            5         0       3  ...   8.0500   NaN         S
#
# [5 rows x 12 columns]

# %%
# pass the DataFrame to 'get_dummies' and specify which columns to dummy (it drops the original columns)
pd.get_dummies(train, columns=['Sex', 'Embarked']).head()
# Out:
#    PassengerId  Survived  Pclass  ... Embarked_C  Embarked_Q  Embarked_S
# 0            1         0       3  ...          0           0           1
# 1            2         1       1  ...          1           0           0
# 2            3         1       3  ...          0           0           1
# 3            4         1       1  ...          0           0           1
# 4            5         0       3  ...          0           0           1
#
# [5 rows x 15 columns]

# %%
# use the 'drop_first' parameter (new in pandas 0.18) to drop the first dummy variable for each feature
pd.get_dummies(train, columns=['Sex', 'Embarked'], drop_first=True).head()
# Out:
#    PassengerId  Survived  Pclass  ... Sex_male  Embarked_Q  Embarked_S
# 0            1         0       3  ...        1           0           1
# 1            2         1       1  ...        0           0           0
# 2            3         1       3  ...        0           0           1
# 3            4         1       1  ...        0           0           1
# 4            5         0       3  ...        1           0           1
#
# [5 rows x 13 columns]

# %% [markdown]
# Know more: [get_dummies](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.get_dummies.html)

# %% [markdown]
# **How to find and remove duplicate rows in pandas**

# %%
# read a dataset of movie reviewers into a DataFrame
user_cols = ['user_id', 'age', 'gender', 'occupation', 'zip_code']
users = pd.read_table('http://bit.ly/movieusers', sep='|', header=None, names=user_cols, index_col='user_id')
users.head()
# Out:
#          age gender  occupation zip_code
# user_id
# 1         24      M  technician    85711
# 2         53      F       other    94043
# 3         23      M      writer    32067
# 4         24      M  technician    43537
# 5         33      F       other    15213

# %%
users.shape
# Out:
# (943, 4)

# %%
# detect duplicate zip codes: True if an item is identical to a previous item
users.zip_code.duplicated().tail()
# Out:
# user_id
# 939    False
# 940     True
# 941    False
# 942    False
# 943    False
# Name: zip_code, dtype: bool

# %%
# count the duplicate items (True becomes 1, False becomes 0)
users.zip_code.duplicated().sum()
# Out:
# 148

# %%
# detect duplicate DataFrame rows: True if an entire row is identical to a previous row
users.duplicated().tail()
# Out:
# user_id
# 939    False
# 940    False
# 941    False
# 942    False
# 943    False
# dtype: bool

# %%
# count the duplicate rows
users.duplicated().sum()
# Out:
# 7

# %% [markdown]
# Logic for duplicated:
#
# * keep='first' (default): Mark duplicates as True except for the first occurrence.
# * keep='last': Mark duplicates as True except for the last occurrence.
# * keep=False: Mark all duplicates as True.

# %%
# examine the duplicate rows (ignoring the first occurrence)
users.loc[users.duplicated(keep='first'), :]
# Out:
#          age gender occupation zip_code
# user_id
# 496       21      F    student    55414
# 572       51      M   educator    20003
# 621       17      M    student    60402
# 684       28      M    student    55414
# 733       44      F      other    60630
# 805       27      F      other    20009
# 890       32      M    student    97301

# %%
# examine the duplicate rows (ignoring the last occurrence)
users.loc[users.duplicated(keep='last'), :]
# Out:
#          age gender occupation zip_code
# user_id
# 67        17      M    student    60402
# 85        51      M   educator    20003
# 198       21      F    student    55414
# 350       32      M    student    97301
# 428       28      M    student    55414
# 437       27      F      other    20009
# 460       44      F      other    60630

# %%
# examine the duplicate rows (including all duplicates)
users.loc[users.duplicated(keep=False), :]
# Out:
#          age gender occupation zip_code
# user_id
# 67        17      M    student    60402
# 85        51      M   educator    20003
# 198       21      F    student    55414
# 350       32      M    student    97301
# 428       28      M    student    55414
# 437       27      F      other    20009
# 460       44      F      other    60630
# 496       21      F    student    55414
# 572       51      M   educator    20003
# 621       17      M    student    60402
# 684       28      M    student    55414
# 733       44      F      other    60630
# 805       27      F      other    20009
# 890       32      M    student    97301

# %%
# drop the duplicate rows (inplace=False by default)
users.drop_duplicates(keep='first').shape
# Out:
# (936, 4)

# %%
users.drop_duplicates(keep='last').shape
# Out:
# (936, 4)

# %%
# only consider a subset of columns when identifying duplicates
users.duplicated(subset=['age', 'zip_code']).sum()
# Out:
# 16

# %%
users.drop_duplicates(subset=['age', 'zip_code']).shape
# Out:
# (927, 4)

# %% [markdown]
# Know more: [drop_duplicates](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.drop_duplicates.html)

# %% [markdown]
# *Created by KRISHNA MORE*
#
# connect me via [linkdein](https://www.linkedin.com/in/krishna-more-a886ba1a9/)
